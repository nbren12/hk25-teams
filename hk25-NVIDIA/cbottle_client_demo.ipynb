# %%
# %pip -q install "git+https://github.com/NVlabs/cBottle.git@nb/xdataset#subdirectory=client"
# %pip install -q easygems
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import cbottle_client
import easygems.healpix as egh

# %%
ds = cbottle_client.open_zarr('login33', 'xarray', 'datasets/inference/zarr')
ds
# Out:
# <xarray.Dataset> Size: 52GB
# Dimensions:  (time: 5840, channel: 45, cell: 49152, dim_0: 1)
# Coordinates:
#   * time     (time) datetime64[ns] 47kB 2000-01-01 ... 2001-12-30T21:00:00
#   * channel  (channel) <U8 1kB 'U1000' 'U850' 'U700' ... 'rsds' 'sst' 'sic'
# Dimensions without coordinates: cell, dim_0
# Data variables:
#     data     (time, channel, cell) float32 52GB dask.array<chunksize=(4, 45, 49152), meta=np.ndarray>
#     healpix  (dim_0) int64 8B dask.array<chunksize=(1,), meta=np.ndarray>

# %%
arr = ds.isel(time=0).data.load()

# %%
as_ds = arr.to_dataset('channel')

# %%
egh.healpix_show(as_ds.Z500)

# %%
egh.healpix_show(as_ds.clivi)
